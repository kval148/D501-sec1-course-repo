# %%
import requests
import json

# %%
with open("data_sample.json") as fp:
    data = json.load(fp)

# %%
formatted_data = {"dataframe_split": data}

# %%
print(formatted_data)
# Out:
# {'dataframe_split': {'columns': ['Unnamed: 0', 'Unnamed: 0.1', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'duration_ms', 'time_signature', 'genre', 'song_name', 'title', 'text_feature'], 'index': [3090, 9214, 9256, 10564, 11591, 10132, 10417, 8390, 2745, 3726], 'data': [[19104, 19104, 0.636, 0.61, 8, -9.665, 1, 0.119, 0.25, 0.000121, 0.113, 0.296, 125.227, 'audio_features', 260160, 3, 'Hiphop', 'Jazz', None, ' Jazz'], [9489, 9489, 0.908, 0.535, 7, -8.509, 0, 0.292, 0.632, 0.0, 0.214, 0.271, 115.016, 'audio_features', 186613, 4, 'Underground Rap', 'Purge', None, ' Purge'], [18957, 18957, 0.926, 0.851, 4, -5.435, 0, 0.0907, 0.0962, 0.00017, 0.113, 0.838, 117.556, 'audio_features', 263267, 4, 'Hiphop', 'Bust A Move', None, ' Bust A Move'], [9531, 9531, 0.847, 0.444, 8, -10.167, 0, 0.492, 0.336, 0.0, 0.0996, 0.667, 115.042, 'audio_features', 117943, 4, 'Underground Rap', '2z Don Corleon',
# ...

# %%
print(data)
# Out:
# {'columns': ['Unnamed: 0', 'Unnamed: 0.1', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'duration_ms', 'time_signature', 'genre', 'song_name', 'title', 'text_feature'], 'index': [3090, 9214, 9256, 10564, 11591, 10132, 10417, 8390, 2745, 3726], 'data': [[19104, 19104, 0.636, 0.61, 8, -9.665, 1, 0.119, 0.25, 0.000121, 0.113, 0.296, 125.227, 'audio_features', 260160, 3, 'Hiphop', 'Jazz', None, ' Jazz'], [9489, 9489, 0.908, 0.535, 7, -8.509, 0, 0.292, 0.632, 0.0, 0.214, 0.271, 115.016, 'audio_features', 186613, 4, 'Underground Rap', 'Purge', None, ' Purge'], [18957, 18957, 0.926, 0.851, 4, -5.435, 0, 0.0907, 0.0962, 0.00017, 0.113, 0.838, 117.556, 'audio_features', 263267, 4, 'Hiphop', 'Bust A Move', None, ' Bust A Move'], [9531, 9531, 0.847, 0.444, 8, -10.167, 0, 0.492, 0.336, 0.0, 0.0996, 0.667, 115.042, 'audio_features', 117943, 4, 'Underground Rap', '2z Don Corleon', None, ' 2z Don Corl
# ...

# %%
results = requests.post("http://localhost:5000/invocations", json=formatted_data)

# %%
print(results)
# Out:
# <Response [200]>

# %%
print(results.json())
# Out:
# {'predictions': ['RnB', 'Rap', 'RnB', 'Underground Rap', 'hardstyle', 'trap', 'Hiphop', 'Rap', 'RnB', 'Hiphop']}
